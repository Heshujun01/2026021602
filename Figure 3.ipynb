# %%
import numpy as np
import matplotlib.pyplot as plt

filenames = ['D10', 'D11', 'D12', 'D13', 'D14', 'D15']#, 'G6P3Na', 'G6P3D11Na', 'G6P3D12Na', 'G6P3K', 'G6P3D11K', 'G6P3D12K']
# 绘制旋转后的直方图
fig, axes = plt.subplots(1, len(filenames), figsize=(6, 4), sharey=True)
# 遍历每个样本 (D9-D15)
for i, file_name in enumerate(filenames):
    data = np.load(f"{file_name}.npz")
    counts = data["counts"]
    bins = data["bins"]

    # 旋转直方图：交换 x 和 y 轴
    if (i > 5) & (i < 9):
        axes[i].barh(
            1-bins[:-1],  # 左边界
            counts/np.max(counts),     # 高度
            height=np.diff(bins),  # 柱宽
            align="edge",
            color='blue',
            alpha=0.25, edgecolor=[], linewidth=0.5
        )
    else :
        axes[i].barh(
            1-bins[:-1],  # 左边界
            counts/np.max(counts),     # 高度
            height=np.diff(bins),  # 柱宽
            align="edge",
            color='black',
            alpha=0.25, edgecolor=[], linewidth=0.5
        )
    bin_centers = (bins[:-1] + bins[1:]) / 2
    
    axes[i].plot(np.exp(-(bin_centers - 0.1569)**2 / (2 * 0.0043**2)), 1 - bin_centers, 'k--', alpha=0.5)
    #axes[i].plot(np.exp(-(bin_centers - 0.2783)**2 / (2 * 0.0043**2)), 1 - bin_centers, 'r--', alpha=0.5)
    #axes[i].plot(np.exp(-(bin_centers - 0.2914)**2 / (2 * 0.0032**2)), 1 - bin_centers, 'r--', alpha=0.5)
    axes[i].grid(False)
    axes[i].set_xticklabels([])
    axes[i].set_xlim(0,1.05)
    axes[i].set_ylim(0.70,1)
    axes[i].set_title(f"{file_name}",fontsize=20)
    
# 调整布局

plt.tight_layout()
plt.savefig('current_norm_hist_3.svg',format='svg',dpi=300)

# %%
import numpy as np
import matplotlib.pyplot as plt

filenames = ['D10', 'D11', 'D12', 'D13', 'D14', 'D15']
# 绘制旋转后的直方图
fig, axes = plt.subplots(1, len(filenames), figsize=(6, 4), sharey=True)
# 遍历每个样本 (D9-D15)
for i, file_name in enumerate(filenames):
    data = np.load(f"{file_name}.npz")
    segment_median = data["segment_median"]
    print(len(segment_median))
    #axes[i].plot(np.exp(-(bin_centers - 0.1566)**2 / (2 * 0.0040**2)), 1 - bin_centers, 'k--', alpha=0.5)
    #axes[i].plot(np.exp(-(bin_centers - 0.2607)**2 / (2 * 0.0094**2)), 1 - bin_centers, 'r--', alpha=0.5)

    # 旋转直方图：交换 x 和 y 轴
    
    counts, bins = np.histogram(segment_median, bins=101, density=False, range=(0, 0.5))
    bin_centers = (bins[:-1] + bins[1:]) / 2  # 计算每个 bin 的中心位置
    # 旋转直方图：交换 x 和 y 轴
    axes[i].barh(
        1-bin_centers,  # 左边界
        counts,     # 高度
        height=np.diff(bins),  # 柱宽
        align="edge",
        color='black',
        alpha=0.25, edgecolor=[], linewidth=0.5
    )
    axes[i].grid(False)
    axes[i].set_xticklabels([])
    #axes[i].set_xlim(0,1.05)
    axes[i].set_ylim(0.7,1)
    axes[i].set_title(f"{file_name}",fontsize=16)
    
# 调整布局

plt.tight_layout()
plt.savefig('event_norm_hist_3.svg',format='svg',dpi=300)
# Out:
# 50
# 61
# 51
# 60
# 92
# 53

# %%
import numpy as np
import matplotlib.pyplot as plt

filenames = ['D10', 'G6P3D11K+180mV', 'G6P3D12K+180mV', 'G6P3D13K+180mV', 'G6P3D14K+180mV', 'D15']
# 绘制旋转后的直方图
fig, axes = plt.subplots(1, len(filenames), figsize=(6, 4), sharey=True)
# 遍历每个样本 (D9-D15)
for i, file_name in enumerate(filenames):
    data = np.load(f"{file_name}.npz")
    counts = data["counts"]
    bins = data["bins"]

    # 旋转直方图：交换 x 和 y 轴
    if (i > 5) & (i < 9):
        axes[i].barh(
            1-bins[:-1],  # 左边界
            counts/np.max(counts),     # 高度
            height=np.diff(bins),  # 柱宽
            align="edge",
            color='blue',
            alpha=0.25, edgecolor=[], linewidth=0.5
        )
    else :
        axes[i].barh(
            1-bins[:-1],  # 左边界
            counts/np.max(counts),     # 高度
            height=np.diff(bins),  # 柱宽
            align="edge",
            color='black',
            alpha=0.25, edgecolor=[], linewidth=0.5
        )
    bin_centers = (bins[:-1] + bins[1:]) / 2
    
    axes[i].plot(np.exp(-(bin_centers - 0.1569)**2 / (2 * 0.0043**2)), 1 - bin_centers, 'k--', alpha=0.5)
    #axes[i].plot(np.exp(-(bin_centers - 0.2783)**2 / (2 * 0.0043**2)), 1 - bin_centers, 'r--', alpha=0.5)
    #axes[i].plot(np.exp(-(bin_centers - 0.2914)**2 / (2 * 0.0032**2)), 1 - bin_centers, 'r--', alpha=0.5)
    axes[i].grid(False)
    axes[i].set_xticklabels([])
    axes[i].set_xlim(0,1.05)
    axes[i].set_ylim(0.70,1)
    axes[i].set_title(f"{file_name}",fontsize=20)
    
# 调整布局

plt.tight_layout()
plt.savefig('current_norm_hist_4.svg',format='svg',dpi=300)

# %%
import numpy as np
import matplotlib.pyplot as plt

filenames = ['D10', 'G6P3D11K+180mV', 'G6P3D12K+180mV', 'G6P3D13K+180mV', 'G6P3D14K+180mV', 'D15']
# 绘制旋转后的直方图
fig, axes = plt.subplots(1, len(filenames), figsize=(6, 4), sharey=True)
# 遍历每个样本 (D9-D15)
for i, file_name in enumerate(filenames):
    data = np.load(f"{file_name}.npz")
    segment_median = data["segment_median"]
    print(len(segment_median))
    #axes[i].plot(np.exp(-(bin_centers - 0.1566)**2 / (2 * 0.0040**2)), 1 - bin_centers, 'k--', alpha=0.5)
    #axes[i].plot(np.exp(-(bin_centers - 0.2607)**2 / (2 * 0.0094**2)), 1 - bin_centers, 'r--', alpha=0.5)

    # 旋转直方图：交换 x 和 y 轴
    
    counts, bins = np.histogram(segment_median, bins=101, density=False, range=(0, 0.5))
    bin_centers = (bins[:-1] + bins[1:]) / 2  # 计算每个 bin 的中心位置
    # 旋转直方图：交换 x 和 y 轴
    axes[i].barh(
        1-bin_centers,  # 左边界
        counts,     # 高度
        height=np.diff(bins),  # 柱宽
        align="edge",
        color='black',
        alpha=0.25, edgecolor=[], linewidth=0.5
    )
    axes[i].grid(False)
    axes[i].set_xticklabels([])
    #axes[i].set_xlim(0,1.05)
    axes[i].set_ylim(0.7,1)
    axes[i].set_title(f"{file_name}",fontsize=16)
    
# 调整布局

plt.tight_layout()
plt.savefig('event_norm_hist_4.svg',format='svg',dpi=300)
# Out:
# 50
# 15
# 22
# 15
# 21
# 53

# %%
import numpy as np
import matplotlib.pyplot as plt

filenames = ['D13K+100mV', 'D13K+120mV', 'D13K+140mV', 'D13K+160mV', 'D13K+180mV']
# 绘制旋转后的直方图
fig, axes = plt.subplots(1, len(filenames), figsize=(6, 4), sharey=True)
# 遍历每个样本 (D9-D15)
for i, file_name in enumerate(filenames):
    data = np.load(f"{file_name}.npz")
    counts = data["counts"]
    bins = data["bins"]

    # 旋转直方图：交换 x 和 y 轴
    if (i > 5) & (i < 9):
        axes[i].barh(
            1-bins[:-1],  # 左边界
            counts/np.max(counts),     # 高度
            height=np.diff(bins),  # 柱宽
            align="edge",
            color='blue',
            alpha=0.25, edgecolor=[], linewidth=0.5
        )
    else :
        axes[i].barh(
            1-bins[:-1],  # 左边界
            counts/np.max(counts),     # 高度
            height=np.diff(bins),  # 柱宽
            align="edge",
            color='#ff0000',
            alpha=0.75, edgecolor=[], linewidth=0.5
        )
    bin_centers = (bins[:-1] + bins[1:]) / 2
    
    axes[i].plot(np.exp(-(bin_centers - 0.1569)**2 / (2 * 0.0043**2)), 1 - bin_centers, 'k--', alpha=0.5)
    #axes[i].plot(np.exp(-(bin_centers - 0.2783)**2 / (2 * 0.0043**2)), 1 - bin_centers, 'r--', alpha=0.5)
    #axes[i].plot(np.exp(-(bin_centers - 0.2914)**2 / (2 * 0.0032**2)), 1 - bin_centers, 'r--', alpha=0.5)
    axes[i].grid(False)
    axes[i].set_xticklabels([])
    axes[i].set_xlim(0,1.05)
    axes[i].set_ylim(0.70,1)
    axes[i].set_title(f"{file_name}",fontsize=20)
    
# 调整布局

plt.tight_layout()
plt.savefig('current_norm_hist_5.svg',format='svg',dpi=300)

# %%
import numpy as np
import matplotlib.pyplot as plt

filenames = ['D13K+100mV', 'D13K+120mV', 'D13K+140mV', 'D13K+160mV', 'D13K+180mV']
# 绘制旋转后的直方图
fig, axes = plt.subplots(1, len(filenames), figsize=(6, 4), sharey=True)
# 遍历每个样本 (D9-D15)
for i, file_name in enumerate(filenames):
    data = np.load(f"{file_name}.npz")
    segment_median = data["segment_median"]
    print(len(segment_median))
    #axes[i].plot(np.exp(-(bin_centers - 0.1566)**2 / (2 * 0.0040**2)), 1 - bin_centers, 'k--', alpha=0.5)
    #axes[i].plot(np.exp(-(bin_centers - 0.2607)**2 / (2 * 0.0094**2)), 1 - bin_centers, 'r--', alpha=0.5)

    # 旋转直方图：交换 x 和 y 轴
    
    counts, bins = np.histogram(segment_median, bins=101, density=False, range=(0, 0.5))
    bin_centers = (bins[:-1] + bins[1:]) / 2  # 计算每个 bin 的中心位置
    # 旋转直方图：交换 x 和 y 轴
    axes[i].barh(
        1-bin_centers,  # 左边界
        counts,     # 高度
        height=np.diff(bins),  # 柱宽
        align="edge",
        color='#ff0000',
        alpha=0.75, edgecolor=[], linewidth=0.5
    )
    axes[i].grid(False)
    axes[i].set_xticklabels([])
    #axes[i].set_xlim(0,1.05)
    axes[i].set_ylim(0.7,1)
    axes[i].set_title(f"{file_name}",fontsize=16)
    
# 调整布局

plt.tight_layout()
plt.savefig('event_norm_hist_5.svg',format='svg',dpi=300)
# Out:
# 15
# 22
# 35
# 35
# 40

# %%
import numpy as np
import matplotlib.pyplot as plt

filenames = ['G6P3D13K+100mV', 'G6P3D13K+120mV', 'G6P3D13K+140mV', 'G6P3D13K+160mV', 'G6P3D13K+180mV']
# 绘制旋转后的直方图
fig, axes = plt.subplots(1, len(filenames), figsize=(6, 4), sharey=True)
# 遍历每个样本 (D9-D15)
for i, file_name in enumerate(filenames):
    data = np.load(f"{file_name}.npz")
    counts = data["counts"]
    bins = data["bins"]

    # 旋转直方图：交换 x 和 y 轴
    if (i > 5) & (i < 9):
        axes[i].barh(
            1-bins[:-1],  # 左边界
            counts/np.max(counts),     # 高度
            height=np.diff(bins),  # 柱宽
            align="edge",
            color='blue',
            alpha=0.25, edgecolor=[], linewidth=0.5
        )
    else :
        axes[i].barh(
            1-bins[:-1],  # 左边界
            counts/np.max(counts),     # 高度
            height=np.diff(bins),  # 柱宽
            align="edge",
            color='#70c2c2',
            alpha=0.75, edgecolor=[], linewidth=0.5
        )
    bin_centers = (bins[:-1] + bins[1:]) / 2
    
    axes[i].plot(np.exp(-(bin_centers - 0.1569)**2 / (2 * 0.0043**2)), 1 - bin_centers, 'k--', alpha=0.5)
    #axes[i].plot(np.exp(-(bin_centers - 0.2783)**2 / (2 * 0.0043**2)), 1 - bin_centers, 'r--', alpha=0.5)
    #axes[i].plot(np.exp(-(bin_centers - 0.2914)**2 / (2 * 0.0032**2)), 1 - bin_centers, 'r--', alpha=0.5)
    axes[i].grid(False)
    axes[i].set_xticklabels([])
    axes[i].set_xlim(0,1.05)
    axes[i].set_ylim(0.70,1)
    axes[i].set_title(f"{file_name}",fontsize=20)
    
# 调整布局

plt.tight_layout()
plt.savefig('current_norm_hist_6.svg',format='svg',dpi=300)

# %%
import numpy as np
import matplotlib.pyplot as plt

filenames = ['G6P3D13K+100mV', 'G6P3D13K+120mV', 'G6P3D13K+140mV', 'G6P3D13K+160mV', 'G6P3D13K+180mV']
# 绘制旋转后的直方图
fig, axes = plt.subplots(1, len(filenames), figsize=(6, 4), sharey=True)
# 遍历每个样本 (D9-D15)
for i, file_name in enumerate(filenames):
    data = np.load(f"{file_name}.npz")
    segment_median = data["segment_median"]
    print(len(segment_median))
    #axes[i].plot(np.exp(-(bin_centers - 0.1566)**2 / (2 * 0.0040**2)), 1 - bin_centers, 'k--', alpha=0.5)
    #axes[i].plot(np.exp(-(bin_centers - 0.2607)**2 / (2 * 0.0094**2)), 1 - bin_centers, 'r--', alpha=0.5)

    # 旋转直方图：交换 x 和 y 轴
    
    counts, bins = np.histogram(segment_median, bins=101, density=False, range=(0, 0.5))
    bin_centers = (bins[:-1] + bins[1:]) / 2  # 计算每个 bin 的中心位置
    # 旋转直方图：交换 x 和 y 轴
    axes[i].barh(
        1-bin_centers,  # 左边界
        counts,     # 高度
        height=np.diff(bins),  # 柱宽
        align="edge",
        color='#70c2c2',
        alpha=1, edgecolor=[], linewidth=0.5
    )
    axes[i].grid(False)
    axes[i].set_xticklabels([])
    #axes[i].set_xlim(0,1.05)
    axes[i].set_ylim(0.7,1)
    axes[i].set_title(f"{file_name}",fontsize=16)
    
# 调整布局

plt.tight_layout()
plt.savefig('event_norm_hist_6.svg',format='svg',dpi=300)
# Out:
# 3
# 5
# 9
# 13
# 15

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 文件名列表
filenames = ['T40', 'D10', 'D11', 'D12', 'D13', 'D14', 'D15', 'C40K', 'G6P3Na', 'G6P3D11Na', 'G6P3D12Na', 'G6P3K', 'G6P3D11K', 'G6P3D12K']

# 创建绘图区域
fig, ax = plt.subplots(figsize=(10, 5))

# 遍历每个样本
all_data = []
positions = []  # 用于记录每个样本的位置
for i, file_name in enumerate(filenames):
    try:
        # 加载数据
        data = np.load(f"{file_name}.npz")
        segment_median = data["segment_median"]
        
        # 计算归一化值
        normalized_values = 1 - segment_median
        
        # 绘制散点图
        ax.plot(i * np.ones(len(normalized_values)), normalized_values, 'o', alpha=0.5, label=file_name)
        
        # 收集数据用于箱型图和小提琴图
        all_data.append(normalized_values)
        positions.append(i)
    
    except FileNotFoundError:
        print(f"File {file_name}.npz not found. Skipping...")

# 添加箱型图
bplot = ax.boxplot(
    all_data,
    positions=positions,
    widths=0.4,
    patch_artist=True,
    #showmeans=True,
    meanline=True,
    medianprops={"color": "black", "linewidth": 1.5},
    boxprops={"facecolor": "white", "alpha": 0.7},
    #whiskerprops={"color": "black", "linewidth": 1},
    #capprops={"color": "black", "linewidth": 1},
    #meanprops={"color": "green", "linewidth": 1.5, "linestyle": "--"}
)

# 添加小提琴图
#vplot = ax.violinplot(
#    all_data,
#    positions=positions,
#    widths=0.8,
#    showmeans=True,
#    showmedians=True
#)
#for pc in vplot['bodies']:
#    pc.set_facecolor('orange')
#    pc.set_edgecolor('black')
#    pc.set_alpha(0.5)

# 设置坐标轴范围
ax.set_ylim(0.70, 0.88)

# 添加标签和标题
ax.set_xticks(range(len(filenames)))
ax.set_xticklabels(filenames, fontsize=24)
ax.set_ylabel("1 - I_norm_median", fontsize=24)
#ax.set_title("Scatter Plot with Boxplot and Violin Plot")

# 调整布局
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

filenames = ['T40', 'D10', 'D11', 'D12', 'D13', 'D14', 'D15', 'C40K', 'G6P3Na', 'G6P3D11Na', 'G6P3D12Na', 'G6P3K', 'G6P3D11K', 'G6P3D12K']
# 绘制旋转后的直方图
fig, axes = plt.subplots(1, len(filenames), figsize=(12, 3), sharey=True)
# 遍历每个样本 (D9-D15)
for i, file_name in enumerate(filenames):
    data = np.load(f"{file_name}.npz")
    segment_median = data["segment_median"]
    #axes[i].plot(np.exp(-(bin_centers - 0.1566)**2 / (2 * 0.0040**2)), 1 - bin_centers, 'k--', alpha=0.5)
    #axes[i].plot(np.exp(-(bin_centers - 0.2607)**2 / (2 * 0.0094**2)), 1 - bin_centers, 'r--', alpha=0.5)

    # 旋转直方图：交换 x 和 y 轴
    
    counts, bins = np.histogram(segment_median, bins=76, density=False, range=(0, 0.5))
    bin_centers = (bins[:-1] + bins[1:]) / 2  # 计算每个 bin 的中心位置
    # 旋转直方图：交换 x 和 y 轴
    axes[i].barh(
        1-bin_centers,  # 左边界
        counts,     # 高度
        height=np.diff(bins),  # 柱宽
        align="edge",
        color='black',
        alpha=0.25, edgecolor=[], linewidth=0.5
    )
    axes[i].grid(False)
    axes[i].set_xticklabels([])
    #axes[i].set_xlim(0,1.05)
    axes[i].set_ylim(0.7,0.86)
    axes[i].set_title(f"{file_name}",fontsize=16)
    
# 调整布局

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 文件名列表
filenames = ['T40K+100mV', 'T40K+120mV', 'T40K+140mV', 'T40K+160mV', 'T40K+180mV',
             'D10K+100mV', 'D10K+120mV', 'D10K+140mV', 'D10K+160mV', 'D10K+180mV',
             'D11K+100mV', 'D11K+120mV', 'D11K+140mV', 'D11K+160mV', 'D11K+180mV',
             'D12K+100mV', 'D12K+120mV', 'D12K+140mV', 'D12K+160mV', 'D12K+180mV',
             'D13K+100mV', 'D13K+120mV', 'D13K+140mV', 'D13K+160mV', 'D13K+180mV',
             'D14K+100mV', 'D14K+120mV', 'D14K+140mV', 'D14K+160mV', 'D14K+180mV',
             'D15K+100mV', 'D15K+120mV', 'D15K+140mV', 'D15K+160mV', 'D15K+180mV']

# 绘制旋转后的直方图
fig, axes = plt.subplots(1, len(filenames), figsize=(15, 3), sharey=True)
# 遍历每个样本 (D9-D15)
for i, file_name in enumerate(filenames):
    data = np.load(f"{file_name}.npz")
    counts = data["counts"]
    bins = data["bins"]

    # 旋转直方图：交换 x 和 y 轴
    if (i+1) % 5 == 0:
        axes[i].barh(
            1-bins[:-1],  # 左边界
            counts/np.max(counts),     # 高度
            height=np.diff(bins),  # 柱宽
            align="edge",
            color='blue',
            alpha=0.5, edgecolor=[], linewidth=0.5
        )
    else :
        axes[i].barh(
            1-bins[:-1],  # 左边界
            counts/np.max(counts),     # 高度
            height=np.diff(bins),  # 柱宽
            align="edge",
            color='black',
            alpha=0.25, edgecolor=[], linewidth=0.5
        )
    bin_centers = (bins[:-1] + bins[1:]) / 2
    
    axes[i].plot(np.exp(-(bin_centers - 0.1566)**2 / (2 * 0.0040**2)), 1 - bin_centers, 'k--', alpha=0.5)
    axes[i].plot(np.exp(-(bin_centers - 0.2783)**2 / (2 * 0.0043**2)), 1 - bin_centers, 'r--', alpha=0.5)
    axes[i].plot(np.exp(-(bin_centers - 0.2914)**2 / (2 * 0.0032**2)), 1 - bin_centers, 'r--', alpha=0.5)
    axes[i].grid(False)
    axes[i].set_xticklabels([])
    axes[i].set_xlim(0,1.05)
    axes[i].set_ylim(0.70,0.9)
    axes[i].set_title(f"{file_name}",fontsize=20)
    
# 调整布局

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.interpolate import UnivariateSpline

# 文件名列表
filenames = ['D10K+100mV', 'D10K+120mV', 'D10K+140mV', 'D10K+160mV', 'D10K+180mV',
             'D11K+100mV', 'D11K+120mV', 'D11K+140mV', 'D11K+160mV', 'D11K+180mV',
             'D12K+100mV', 'D12K+120mV', 'D12K+140mV', 'D12K+160mV', 'D12K+180mV',
             'D13K+100mV', 'D13K+120mV', 'D13K+140mV', 'D13K+160mV', 'D13K+180mV',
             'D14K+100mV', 'D14K+120mV', 'D14K+140mV', 'D14K+160mV', 'D14K+180mV',
             'D15K+100mV', 'D15K+120mV', 'D15K+140mV', 'D15K+160mV', 'D15K+180mV']

a = np.array([10, 11, 12, 13, 14, 15])
#b = np.array([0.945, 0.97, 0.99, 1, 1.01])/1.01
b = np.array([0, 10/11, 0, 0, 1])

# 计算外积并展平
nt_position = np.outer(a, b).flatten()

# 创建绘图区域
fig, ax = plt.subplots(figsize=(9, 3))

# 遍历每个样本
all_data = []
positions = []  # 用于记录每个样本的位置
median_values = []
for i, file_name in enumerate(filenames):
    try:
        # 加载数据
        data = np.load(f"{file_name}.npz")
        segment_median = data["segment_median"]
        
        # 计算归一化值
        normalized_values = 1 - segment_median
        
        # 绘制散点图
        #ax.plot(nt_position[i] * np.ones(len(normalized_values)), normalized_values, 'o', alpha=0.5, label=file_name)
        
        # 收集数据用于箱型图和小提琴图
        all_data.append(normalized_values)
        positions.append(nt_position[i])
        
        # 计算中位数
        median_values.append(np.median(normalized_values))
        
    except FileNotFoundError:
        print(f"File {file_name}.npz not found. Skipping...")

# 添加箱型图
bplot = ax.boxplot(
    all_data,
    positions=positions,
    widths=0.1,
    patch_artist=True,
    #showmeans=True,
    meanline=True,
    medianprops={"color": "black", "linewidth": 1.5},
    boxprops={"facecolor": "white", "alpha": 0.7}
    #whiskerprops={"color": "black", "linewidth": 1},
    #capprops={"color": "black", "linewidth": 1},
    #meanprops={"color": "green", "linewidth": 1.5, "linestyle": "--"}
)

# 添加小提琴图
#vplot = ax.violinplot(
#    all_data,
#    positions=positions,
#    widths=0.8,
#    showmeans=True,
#    showmedians=True
#)
#for pc in vplot['bodies']:
#    pc.set_facecolor('white')
#    pc.set_edgecolor('black')
#    pc.set_alpha(0.5)

# 对数据点进行排序
sorted_indices = np.argsort(positions)
sorted_positions = np.array(positions)[sorted_indices]
sorted_medians = np.array(median_values)[sorted_indices]

if 0:
    # 创建样条插值（s=0 表示插值通过所有点，s>0 表示平滑拟合）
    # 可以调整 s 参数来控制平滑程度
    spline = UnivariateSpline(sorted_positions, sorted_medians, s=0, k=3)  # k=3 表示三次样条
    
    # 生成平滑的插值点
    smooth_positions = np.linspace(sorted_positions.min(), sorted_positions.max(), 300)
    smooth_medians = spline(smooth_positions)
    
    # 绘制样条插值曲线
    ax.plot(smooth_positions, smooth_medians, 'r-', linewidth=2, alpha=0.8, 
            label='Median Spline Trend')

# 设置坐标轴范围
ax.set_xlim(9, 15.5)
ax.set_ylim(0.70, 0.95)

# 添加标签和标题
#ax.set_xticks(range(10,16))
#ax.set_xticklabels(filenames, fontsize=24)
ax.set_ylabel("1 - I_norm_median", fontsize=20)
#ax.set_title("Scatter Plot with Boxplot and Violin Plot")

# 调整布局
plt.plot([9,16],[1-0.1566,1-0.1566],'k--')
plt.plot([10,10],[0.7,0.95],'k--')
plt.plot([11,11],[0.7,0.95],'k--')
plt.plot([12,12],[0.7,0.95],'k--')
plt.plot([13,13],[0.7,0.95],'k--')
plt.plot([14,14],[0.7,0.95],'k--')
plt.plot([15,15],[0.7,0.95],'k--')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 文件名列表
filenames = ['D10K+100mV', 'D10K+120mV', 'D10K+140mV', 'D10K+160mV', 'D10K+180mV',
             'D11K+100mV', 'D11K+120mV', 'D11K+140mV', 'D11K+160mV', 'D11K+180mV',
             'D12K+100mV', 'D12K+120mV', 'D12K+140mV', 'D12K+160mV', 'D12K+180mV',
             'D13K+100mV', 'D13K+120mV', 'D13K+140mV', 'D13K+160mV', 'D13K+180mV',
             'D14K+100mV', 'D14K+120mV', 'D14K+140mV', 'D14K+160mV', 'D14K+180mV',
             'D15K+100mV', 'D15K+120mV', 'D15K+140mV', 'D15K+160mV', 'D15K+180mV']

# 绘制旋转后的直方图
fig, axes = plt.subplots(1, len(filenames), figsize=(10, 4), sharey=True)
# 遍历每个样本 (D9-D15)
for i, file_name in enumerate(filenames):
    data = np.load(f"{file_name}.npz")
    segment_median = data["segment_median"]
    #axes[i].plot(np.exp(-(bin_centers - 0.1566)**2 / (2 * 0.0040**2)), 1 - bin_centers, 'k--', alpha=0.5)
    #axes[i].plot(np.exp(-(bin_centers - 0.2607)**2 / (2 * 0.0094**2)), 1 - bin_centers, 'r--', alpha=0.5)

    # 旋转直方图：交换 x 和 y 轴
    
    counts, bins = np.histogram(segment_median, bins=76, density=False, range=(0, 0.5))
    bin_centers = (bins[:-1] + bins[1:]) / 2  # 计算每个 bin 的中心位置
    # 旋转直方图：交换 x 和 y 轴
    axes[i].barh(
        1-bin_centers,  # 左边界
        counts,     # 高度
        height=np.diff(bins),  # 柱宽
        align="edge",
        color='black',
        alpha=0.25, edgecolor=[], linewidth=0.5
    )
    axes[i].grid(False)
    axes[i].set_xticklabels([])
    #axes[i].set_xlim(0,1.05)
    axes[i].set_ylim(0.7,0.86)
    axes[i].set_title(f"{file_name}",fontsize=16)
    
# 调整布局

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

colors = ['#4d1919', '#861313', '#861313', '#cc0000', '#cc0000', '#ff0000', '#ff0000', '#df2020', '#bf4040']
nt_position = [10, 11, 11, 12, 12, 13, 13, 14, 15]
data = np.array([0.1557, 0.2306, 0.2465, 0.2290, 0.2373, 0.1870, 0.1989, 0.1870, 0.1636])
data_rms = np.array([0.0048, 0.0052, 0.0042, 0.0044, 0.0043, 0.0041, 0.0040, 0.0040, 0.0040])
    
fig, ax = plt.subplots(figsize=(4, 4))

# 绘制误差线
for col in range(data.shape[0]):
    ax.errorbar(nt_position[col], data[col], data_rms[col], fmt='o', 
                linewidth=2, capsize=6, color=colors[col], markersize=8)

# 添加参考线
plt.axhline(y=0.1569, color='k', linestyle='--', linewidth=2, alpha=0.5)

# 计算平均值
unique_positions = sorted(list(set(nt_position)))
avg_values = []

# 按位置分组计算平均值
for pos in unique_positions:
    indices = [i for i, x in enumerate(nt_position) if x == pos]
    values = [data[i] for i in indices]
    avg_values.append(np.mean(values))

# 扩展数据：在两边各延伸一步
if len(unique_positions) > 1:
    step_size = 0.5  # 固定步长
    
    # 创建扩展的位置和值
    extended_positions = [unique_positions[0] - step_size] + unique_positions + [unique_positions[-1] + step_size]
    extended_values = [avg_values[0]] + avg_values + [avg_values[-1]]
    
    # 绘制扩展的阶梯状平均值线
    plt.step(extended_positions, extended_values, 'r--', linewidth=2, alpha=0.5, where='mid')

plt.xlim(9.5, 15.5)
plt.ylim(0.075,0.275)

plt.xlabel('Position', fontsize=14)
plt.ylabel('1 - Normalized Current', fontsize=14)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig('step_normal.svg',format='svg',dpi=300)

# %%
import numpy as np
import matplotlib.pyplot as plt

colors = ['#14b8b8', '#33cccc', '#70c2c2', '#178282']
fmts = ['^','s','p','h','o']
nt_position = [11, 12, 13, 14]
data = np.array([
    [0.1515, 0.1683, 0.1929, 0.2111],
    [0.1768, 0.1923, 0.2055, 0.2248],
    [0.0990, 0.1090, 0.1837, np.nan],
    [0.1993, 0.2103, np.nan, np.nan]
])

data_rms = np.array([
    [0.0048, 0.0041, 0.0038, 0.0032],
    [0.0044, 0.0037, 0.0035, 0.0033],
    [0.0040, 0.0043, 0.0042, np.nan],
    [0.0039, 0.0036, np.nan, np.nan]
])

fig, ax = plt.subplots(figsize=(4, 4))

# 绘制误差线
for row in range(data.shape[0]):
    for col in range(data.shape[1]):
        # 检查是否为有效数据
        if not np.isnan(data[row, col]) and not np.isnan(data_rms[row, col]):
            ax.errorbar(nt_position[col], data[row, col], data_rms[row, col], 
                       fmt='o', linewidth=2, capsize=6, color=colors[col], 
                       markersize=8, label=f'Sample {row+1}' if col == 0 else "")

# 添加参考线
plt.axhline(y=0.1569, color='k', linestyle='--', linewidth=2, alpha=0.5)
plt.step(extended_positions, extended_values, 'r--', linewidth=2, alpha=0.5, where='mid')

# 设置坐标轴范围
plt.xlim(9.5, 15.5)
plt.ylim(0.075,0.275)

# 添加标签和美化
plt.xlabel('Position', fontsize=14)
plt.ylabel('1 - Normalized Current', fontsize=14)

plt.grid(True, alpha=0.3)
plt.tight_layout()

# 保存图形
plt.savefig('step_G6.svg', format='svg', dpi=300, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

colors = ['#4d1919', '#861313', '#861313', '#cc0000', '#cc0000', '#ff0000', '#ff0000', '#df2020', '#bf4040']
colors2 = ['#70c2c2']
fmts = ['^','s','p','h','o']
voltages = [100, 120, 140, 160, 180]

data_D13 = np.array([
    [0.2450, 0.2915],
    [0.2098, 0.2302],
    [0.1872, 0.2090],
    [0.1765, 0.1924],
    [0.1870, 0.1989]
])

data_D13_rms = np.array([
    [0.0054, 0.0094],
    [0.0066, 0.0051],
    [0.0051, 0.0047],
    [0.0042, 0.0040],
    [0.0041, 0.0040]
])
    
data_D13_G6 = np.array([
    [0.1002, np.nan, np.nan, np.nan, np.nan, np.nan],
    [0.1037, 0.1219, np.nan, np.nan, np.nan, np.nan],
    [0.1034, 0.1295, 0.1459, np.nan, np.nan, np.nan],
    [0.0946, 0.1178, 0.1304, 0.1425, 0.1576, np.nan],
    [0.1138, 0.1379, 0.1523, 0.1684, 0.1938, 0.2106]
])

data_D13_G6_rms = np.array([
    [0.0060, np.nan, np.nan, np.nan, np.nan, np.nan],
    [0.0055, 0.0083, np.nan, np.nan, np.nan, np.nan],
    [0.0088, 0.0070, 0.0057, np.nan, np.nan, np.nan],
    [0.0070, 0.0082, 0.0036, 0.0059, 0.0059, np.nan],
    [0.0115, 0.0069, 0.0049, 0.0063, 0.0053, 0.0044]
])

fig, ax = plt.subplots(figsize=(4, 4))

# 绘制误差线
for row in range(data_D13.shape[0]):
    for col in range(data_D13.shape[1]):
        # 检查是否为有效数据
        if not np.isnan(data_D13[row, col]) and not np.isnan(data_D13_rms[row, col]):
            ax.errorbar(voltages[row], data_D13[row, col], data_D13_rms[row, col], 
                       fmt=fmts[row], linewidth=2, capsize=6, color='#ff0000', alpha=0.75,
                       markersize=8, label=f'Sample {row+1}' if col == 0 else "")

for row in range(data_D13_G6.shape[0]):
    for col in range(data_D13_G6.shape[1]):
        # 检查是否为有效数据
        if not np.isnan(data_D13_G6[row, col]) and not np.isnan(data_D13_G6_rms[row, col]):
            ax.errorbar(voltages[row], data_D13_G6[row, col], data_D13_G6_rms[row, col], 
                       fmt=fmts[row], linewidth=2, capsize=6, color='#70c2c2', alpha=0.75,
                       markersize=8, label=f'Sample {row+1}' if col == 0 else "")

# 添加参考线
plt.axhline(y=0.1569, color='k', linestyle='--', linewidth=2, alpha=0.5)

# 设置坐标轴范围
plt.xlim(90, 190)
plt.ylim(0.075,0.275)

# 添加标签和美化
plt.xlabel('Voltage (mV)', fontsize=14)
plt.ylabel('1 - Normalized Current', fontsize=14)

plt.grid(True, alpha=0.3)
plt.tight_layout()

# 保存图形
plt.savefig('voltage_D13.svg', format='svg', dpi=300, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import UnivariateSpline, interp1d

colors = ['#4d1919', '#4d1919', '#861313', '#861313', '#cc0000', '#cc0000', '#ff0000', '#ff0000', '#df2020', '#bf4040']
colors2 = ['#70c2c2']
fmts = ['^','s','p','h','o']

nt_position = [10,10,11,11,12,12,13,13,14,15]
shifted_factor = [14.2,14.4,14.6,14.8,15]
# 创建数据矩阵
data = np.array([
    [0.1819, np.nan, np.nan, 0.2198, 0.1938, np.nan, 0.2450, np.nan, 0.2494, 0.1724],#100
    [0.1851, 0.2026, 0.2027, 0.2082, 0.1898, 0.2072, 0.2098, 0.2302, 0.2210, 0.1633],#120
    [0.1384, np.nan, 0.2085, 0.2170, 0.2022, np.nan, 0.1872, 0.2090, 0.2008, 0.1508],#140
    [0.1384, 0.1545, 0.2093, 0.2296, 0.2158, np.nan, 0.1765, 0.1924, 0.1865, 0.1543],#160
    [0.1557, np.nan, 0.2306, 0.2465, 0.2290, 0.2373, 0.1870, 0.1989, 0.1867, 0.1636]#180
])
data_rms = np.array([
    [0.0122, np.nan, np.nan, 0.0051, 0.0051, np.nan, 0.0054, np.nan, 0.0060, 0.0050],
    [0.0091, 0.0150, 0.0065, 0.0049, 0.0055, 0.0046, 0.0066, 0.0051, 0.0050, 0.0049],
    [0.0088, np.nan, 0.0074, 0.0047, 0.0052, np.nan, 0.0051, 0.0047, 0.0047, 0.0039],
    [0.0045, 0.0057, 0.0052, 0.0045, 0.0041, np.nan, 0.0042, 0.0048, 0.0040, 0.0037],
    [0.0048, np.nan, 0.0052, 0.0042, 0.0044, 0.0043, 0.0041, 0.0040, 0.0037, 0.0040]
])

fig, ax = plt.subplots(figsize=(4, 4))

for row in range(data.shape[0]):
    for col in range(data.shape[1]):
    # 检查是否为有效数据
        if not np.isnan(data[row, col]) and not np.isnan(data_rms[row, col]):
            plt.errorbar(nt_position[col]*shifted_factor[row]/15, data[row, col], data_rms[row, col],
                         fmt=fmts[row],linewidth=2, capsize=4, color=colors[col], markersize=4)
#plt.plot([9,15],[0.1500,0.1500],'k--')
plt.xlim(9.75,15)
plt.ylim(0.075,0.275)

# 处理重复 x 值的函数
def handle_duplicates_for_spline(x_data, y_data):
    """处理样条插值中的重复 x 值"""
    x_data = np.array(x_data)
    y_data = np.array(y_data)
    
    # 创建字典来存储每个 x 值对应的 y 值列表
    x_dict = {}
    for x, y in zip(x_data, y_data):
        if x not in x_dict:
            x_dict[x] = []
        x_dict[x].append(y)
    
    # 对每个 x 值取平均
    unique_x = []
    averaged_y = []
    
    for x_val in sorted(x_dict.keys()):
        unique_x.append(x_val)
        averaged_y.append(np.mean(x_dict[x_val]))
    
    return np.array(unique_x), np.array(averaged_y)

# 收集所有数据点
all_x = []
all_y = []

for row in range(data.shape[0]):
    row_data = data[row, :]
    valid_indices = ~np.isnan(row_data)
    valid_nt_position = np.array(nt_position)[valid_indices]
    valid_row_data = row_data[valid_indices]
    
    x_positions = np.array(valid_nt_position) * shifted_factor[row] / 15
    
    all_x.extend(x_positions)
    all_y.extend(valid_row_data)

# 处理重复值
x_processed, y_processed = handle_duplicates_for_spline(all_x, all_y)

# 进行样条插值
if len(x_processed) > 3:
    try:
        spline = UnivariateSpline(x_processed, y_processed, s=0.001, k=4)
        x_smooth = np.linspace(9.85, max(x_processed), 300)
        y_smooth = spline(x_smooth)
        
        # 绘制结果
        plt.plot(x_smooth, y_smooth, 'k-', linewidth=2, label='Spline Fit')
        plt.xlabel('Position', fontsize=14)
        plt.ylabel('1 - Normalized Current', fontsize=14)
        #plt.legend()
        plt.grid(True, alpha=0.3)
        
        print(f"处理前数据点: {len(all_x)}")
        print(f"处理后数据点: {len(x_processed)}")
        print("重复值已通过平均处理")
        
    except Exception as e:
        print(f"样条插值失败: {e}")
else:
    print("数据点太少无法进行样条插值")\

plt.savefig('spline_normal.svg', format='svg', dpi=300, bbox_inches='tight')
# Out:
# 处理前数据点: 42
# 处理后数据点: 30
# 重复值已通过平均处理

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import UnivariateSpline

# 设置中文字体和图像分辨率（可选）
plt.rcParams['svg.fonttype'] = 'none'  # 保留文本为可编辑文本而非路径

# 颜色和标记设置
colors = ['#4d1919', '#4d1919', '#861313', '#861313', '#cc0000', '#cc0000', '#ff0000', '#ff0000', '#df2020', '#bf4040']
colors2 = ['#70c2c2']
fmts = ['^', 's', 'p', 'h', 'o']  # 每行使用一种标记

nt_position = [10, 10, 11, 11, 12, 12, 13, 13, 14, 15]
shifted_factor = [14.2, 14.4, 14.6, 14.8, 15.0]

# 创建数据矩阵
data = np.array([
    [0.1819, np.nan, np.nan, 0.2198, 0.1938, 0.2079, 0.2450, np.nan, 0.2494, 0.1724],
    [0.1851, 0.2026, 0.2027, 0.2082, 0.1898, 0.2072, 0.2098, 0.2302, 0.2210, 0.1633],
    [0.1384, np.nan, 0.2085, 0.2170, 0.2022, np.nan, 0.1872, 0.2090, 0.2008, 0.1508],
    [0.1384, 0.1545, 0.2093, 0.2296, 0.2158, np.nan, 0.1765, 0.1924, 0.1865, 0.1543],
    [0.1557, np.nan, 0.2306, 0.2465, 0.2290, 0.2373, 0.1870, 0.1989, 0.1870, 0.1636]
])
data_rms = np.array([
    [0.0122, np.nan, np.nan, 0.0051, 0.0051, 0.0064, 0.0054, np.nan, 0.0060, 0.0050],
    [0.0091, 0.0150, 0.0065, 0.0049, 0.0055, 0.0046, 0.0066, 0.0051, 0.0050, 0.0049],
    [0.0088, np.nan, 0.0074, 0.0047, 0.0052, np.nan, 0.0051, 0.0047, 0.0047, 0.0039],
    [0.0045, 0.0057, 0.0052, 0.0045, 0.0041, np.nan, 0.0042, 0.0048, 0.0040, 0.0037],
    [0.0048, np.nan, 0.0052, 0.0042, 0.0044, 0.0043, 0.0041, 0.0040, 0.0040, 0.0040]
])

# 创建图形
fig, ax = plt.subplots(figsize=(4, 4))

# 绘制每个数据点（带误差棒）
for row in range(data.shape[0]):
    for col in range(data.shape[1]):
        if not np.isnan(data[row, col]) and not np.isnan(data_rms[row, col]):
            x_pos = nt_position[col] * shifted_factor[row] / 15
            plt.errorbar(x_pos, data[row, col], yerr=data_rms[row, col],
                         fmt=fmts[row], linewidth=2, capsize=4,
                         color=colors[col], markersize=4, zorder=3)

# 收集所有有效数据点用于样条插值
all_x = []
all_y = []
for row in range(data.shape[0]):
    valid_indices = ~np.isnan(data[row, :])
    valid_nt_pos = np.array(nt_position)[valid_indices]
    x_positions = valid_nt_pos * shifted_factor[row] / 15
    all_x.extend(x_positions)
    all_y.extend(data[row, valid_indices])

# 处理重复 x 值：对相同 x 的 y 取平均
def handle_duplicates_for_spline(x_data, y_data):
    x_dict = {}
    for x, y in zip(x_data, y_data):
        if x not in x_dict:
            x_dict[x] = []
        x_dict[x].append(y)
    unique_x = sorted(x_dict.keys())
    averaged_y = [np.mean(x_dict[x]) for x in unique_x]
    return np.array(unique_x), np.array(averaged_y)

x_processed, y_processed = handle_duplicates_for_spline(all_x, all_y)

# 样条插值
if len(x_processed) > 3:
    try:
        spline = UnivariateSpline(x_processed, y_processed, s=0.001, k=4)
        x_smooth = np.linspace(9.85, max(x_processed), 300)
        y_smooth = spline(x_smooth)
        plt.plot(x_smooth, y_smooth, 'k-', linewidth=2, label='Spline Fit', zorder=2)
        print(f"处理前数据点: {len(all_x)}")
        print(f"处理后数据点: {len(x_processed)}")
        print("重复值已通过平均处理")
    except Exception as e:
        print(f"样条插值失败: {e}")
else:
    print("数据点太少无法进行样条插值")

# 设置坐标轴范围
plt.xlim(9.75, 15)
plt.ylim(0.075, 0.275)

# 设置坐标轴标签
plt.xlabel('Position', fontsize=14)
plt.ylabel('1 - Normalized Current', fontsize=14)

# === 创建图例 ===
from matplotlib.lines import Line2D

# 定义每一行（shifted_factor）的图例项
labels_row = [f'Shift Factor {sf}' for sf in shifted_factor]
legend_elements = []

# 添加每种标记（代表不同 shifted_factor）
for i, fmt in enumerate(fmts[:len(shifted_factor)]):
    legend_elements.append(
        Line2D([0], [0], marker=fmt, color='w', markerfacecolor='black',
               markersize=8, linestyle='None', label=labels_row[i])
    )

# 添加样条曲线图例
legend_elements.append(Line2D([0], [0], color='k', lw=2, label='Spline Fit'))

# 显示图例
plt.legend(handles=legend_elements, loc='upper right', fontsize=10, frameon=True, fancybox=True, shadow=False)

# 添加网格
plt.grid(True, alpha=0.3)

# 保存图像（保留文本可编辑）
plt.tight_layout()
plt.savefig('spline_normal.svg', format='svg', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# 处理前数据点: 43
# 处理后数据点: 30
# 重复值已通过平均处理

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import UnivariateSpline, interp1d

nt_position = [10,11,11,12,12,13,13,14,15]
shifted_factor = [14.2,14.4,14.6,14.8,15]
# 创建数据矩阵
data = np.array([
    [0.1739, np.nan, 0.2198, 0.1938, np.nan, 0.2452, np.nan, 0.2494, 0.1724],
    [0.1884, 0.1993, 0.2076, 0.1896, 0.2063, 0.2096, 0.2299, 0.2210, 0.1633],
    [0.1383, 0.2085, 0.2170, 0.2022, np.nan, 0.1872, 0.2090, 0.1999, 0.1508],
    [0.1386, 0.2090, 0.2300, 0.2154, np.nan, 0.1766, 0.1932, 0.1865, 0.1548],
    [0.1557, 0.2305, 0.2464, 0.2295, 0.2172, 0.1870, 0.1990, 0.1867, 0.1636]
])

for row in range(data.shape[0]):
    row_data = data[row, :]
    plt.plot(np.array(nt_position)*shifted_factor[row]/15,row_data,'o')

#plt.plot([9,15],[0.1500,0.1500],'k--')
plt.xlim(9.75,15)
plt.ylim(0.095,0.275)

# 处理重复 x 值的函数
def handle_duplicates_for_spline(x_data, y_data):
    """处理样条插值中的重复 x 值"""
    x_data = np.array(x_data)
    y_data = np.array(y_data)
    
    # 创建字典来存储每个 x 值对应的 y 值列表
    x_dict = {}
    for x, y in zip(x_data, y_data):
        if x not in x_dict:
            x_dict[x] = []
        x_dict[x].append(y)
    
    # 对每个 x 值取平均
    unique_x = []
    averaged_y = []
    
    for x_val in sorted(x_dict.keys()):
        unique_x.append(x_val)
        averaged_y.append(np.mean(x_dict[x_val]))
    
    return np.array(unique_x), np.array(averaged_y)

# 收集所有数据点
all_x = []
all_y = []

for row in range(data.shape[0]):
    row_data = data[row, :]
    valid_indices = ~np.isnan(row_data)
    valid_nt_position = np.array(nt_position)[valid_indices]
    valid_row_data = row_data[valid_indices]
    
    x_positions = np.array(valid_nt_position) * shifted_factor[row] / 15
    
    all_x.extend(x_positions)
    all_y.extend(valid_row_data)

# 处理重复值
x_processed, y_processed = handle_duplicates_for_spline(all_x, all_y)

# 进行样条插值
if len(x_processed) > 3:
    try:
        spline = UnivariateSpline(x_processed, y_processed, s=0.001, k=4)
        x_smooth = np.linspace(9.85, max(x_processed), 300)
        y_smooth = spline(x_smooth)
        
        # 绘制结果
        plt.plot(x_smooth, y_smooth, 'k-', linewidth=2, label='Spline Fit')
        plt.xlabel('Position')
        plt.ylabel('Normalized Current')
        #plt.legend()
        plt.grid(True, alpha=0.3)
        plt.show()
        
        print(f"处理前数据点: {len(all_x)}")
        print(f"处理后数据点: {len(x_processed)}")
        print("重复值已通过平均处理")
        
    except Exception as e:
        print(f"样条插值失败: {e}")
else:
    print("数据点太少无法进行样条插值")
# Out:
# 处理前数据点: 40
# 处理后数据点: 30
# 重复值已通过平均处理

# %%
G6P3D11_position = [11, 11, 11, 11, 11, 11]
G6P3D11 = np.array([
    [0.1186, np.nan, np.nan, np.nan, np.nan, np.nan],
	[0.1037, 0.1219, np.nan, np.nan, np.nan, np.nan],
	[0.1029, 0.1288, 0.1451, np.nan, np.nan, np.nan],
    [0.1036, 0.1268, 0.1394, 0.1515, 0.1666, np.nan],
	[0.1140, 0.1370, 0.1524, 0.1682, 0.1938, 0.2106]
])
G6P3D11_rms = np.array([
    [0.0070, np.nan, np.nan, np.nan, np.nan, np.nan],
	[0.0055, 0.0083, np.nan, np.nan, np.nan, np.nan],
	[0.0088, 0.0070, 0.0057, np.nan, np.nan, np.nan],
    [0.0070, 0.0082, 0.0059, 0.0036, 0.0059, np.nan],
	[0.0116, 0.0062, 0.0054, 0.0051, 0.0053, 0.0043]
])
for col in range(data.shape[1]):
    if col > 0 and col < 3:
        col_data = data[:,col]
        #plt.plot(np.array(nt_position[col])*shifted_factor/15,col_data,'ko')

for row in range(G6P3D11.shape[0]):
    plt.errorbar(np.array(G6P3D11_position)*shifted_factor[row]/15,G6P3D11[row,:],G6P3D11_rms[row,:],fmt='o',markerfacecolor='none')
    
plt.plot(x_smooth, y_smooth, 'k--', linewidth=1, label='Spline Fit')
plt.plot(x_smooth+0.796, y_smooth, 'k-', linewidth=1, label='Spline Fit')
#plt.plot(x_smooth+1, y_smooth, '--', linewidth=1, label='Spline Fit')
#plt.plot([9,15],[0.1500,0.1500],'k--')
plt.xlim(9.75,15)
plt.ylim(0.105,0.275)
plt.xlabel('Position')
plt.ylabel('Normalized Current')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
G6P3D12_position = [12, 12, 12, 12]
G6P3D12 = np.array([
    [0.1741, 0.1853, np.nan, np.nan],
    [0.1490, 0.1606, 0.1616, 0.1969],
    [0.1760, 0.1937, 0.2307, np.nan],
    [0.1448, 0.1582, 0.1778, 0.2074],
    [0.1759, 0.1949, 0.2062, 0.2248]
])

G6P3D12_rms = np.array([
    [0.0072, 0.0058, np.nan, np.nan],
    [0.0056, 0.0048, 0.0227, 0.0041],
    [0.0078, 0.0051, 0.0073, np.nan],
    [0.0071, 0.0057, 0.0069, 0.0074],
    [0.0101, 0.0051, 0.0046, 0.0066]
])

for col in range(data.shape[1]):
    if col > 2 and col < 4:
        col_data = data[:,col]
        #plt.plot(np.array(nt_position[col])*shifted_factor/15,col_data,'ko')

for row in range(G6P3D12.shape[0]):
    plt.errorbar(np.array(G6P3D12_position)*shifted_factor[row]/15,G6P3D12[row,:],G6P3D12_rms[row,:],fmt='o',markerfacecolor='none')
        
plt.plot(x_smooth, y_smooth, 'k--', linewidth=1, label='Spline Fit')
plt.plot(x_smooth+0.796, y_smooth, 'k-', linewidth=1, label='Spline Fit')
#plt.plot(x_smooth+1, y_smooth, '--', linewidth=1, label='Spline Fit')
plt.xlim(9.75,15)
plt.ylim(0.105,0.275)
plt.xlabel('Position')
plt.ylabel('Normalized Current')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
G6P3D13_position = [13, 13, 13, 13, 13, 13]

G6P3D13 = np.array([
    [0.1002, np.nan, np.nan, np.nan, np.nan, np.nan],
    [0.1037, 0.1219, np.nan, np.nan, np.nan, np.nan],#0.2401
    [0.1034, 0.1295, 0.1459, np.nan, np.nan, np.nan],
    [0.0946, 0.1178, 0.1304, 0.1425, 0.1576, np.nan],
    [0.1138, 0.1379, 0.1523, 0.1684, 0.1938, 0.2106]
])

G6P3D13_rms = np.array([
    [0.0060, np.nan, np.nan, np.nan, np.nan, np.nan],
    [0.0055, 0.0083, 0.0193, np.nan, np.nan, np.nan],
    [0.0088, 0.0070, 0.0057, np.nan, np.nan, np.nan],
    [0.0070, 0.0082, 0.0036, 0.0059, 0.0059, np.nan],
    [0.0115, 0.0069, 0.0049, 0.0063, 0.0053, 0.0044]
])
for col in range(data.shape[1]):
    if col > 4 and col < 6:
        col_data = data[:,col]
        #plt.plot(np.array(nt_position[col])*shifted_factor/15,col_data,'ko')

for row in range(G6P3D13.shape[0]):
    plt.errorbar(np.array(G6P3D13_position)*shifted_factor[row]/15,G6P3D13[row,:],G6P3D13_rms[row,:],fmt='o',markerfacecolor='none')
         
plt.plot(x_smooth, y_smooth, 'k--', linewidth=1, label='Spline Fit')
plt.plot(x_smooth+0.796, y_smooth, 'k-', linewidth=1, label='Spline Fit')
#plt.plot(x_smooth+1, y_smooth, '--', linewidth=1, label='Spline Fit')
plt.xlim(9.75,15)
plt.ylim(0.105,0.275)
plt.xlabel('Position')
plt.ylabel('Normalized Current')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
G6P3D14_position = [14, 14, 14, 14, 14]
G6P3D14 = np.array([
    [0.1991, 0.2075, np.nan, np.nan, np.nan],
    [0.1736, 0.1880, np.nan, np.nan, np.nan],#0.2002
    [0.1560, 0.1699, 0.1829, np.nan, np.nan],
    [0.1495, 0.1819, np.nan, np.nan, np.nan],
    [0.1252, 0.1341, 0.1491, 0.1760, 0.1989]
])
G6P3D14_rms = np.array([
    [0.0053, 0.0084, np.nan, np.nan, np.nan],
    [0.0084, 0.0045, 0.0062, np.nan, np.nan],
    [0.0079, 0.0055, 0.0103, np.nan, np.nan],
    [0.0094, 0.0120, np.nan, np.nan, np.nan],
    [0.0261, 0.0070, 0.0057, 0.0027, 0.0035]
])
for col in range(data.shape[1]):
    if col > 6 and col < 8:
        col_data = data[:,col]
        #plt.plot(np.array(nt_position[col])*shifted_factor/15,col_data,'ko')

for row in range(G6P3D14.shape[0]):
    plt.errorbar(np.array(G6P3D14_position)*shifted_factor[row]/15,G6P3D14[row,:],G6P3D14_rms[row,:],fmt='o',markerfacecolor='none')
        
plt.plot(x_smooth, y_smooth, 'k--', linewidth=1, label='Spline Fit')
plt.plot(x_smooth+0.796, y_smooth, 'k-', linewidth=1, label='Spline Fit')
#plt.plot(x_smooth+1, y_smooth, '--', linewidth=1, label='Spline Fit')
plt.xlim(9.75,15)
plt.ylim(0.105,0.275)
plt.xlabel('Position')
plt.ylabel('Normalized Current')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
colors = ['#14b8b8', '#33cccc', '#70c2c2', '#178282']
fmts = ['^','s','p','h','o']

fig, ax = plt.subplots(figsize=(4, 4))

for row in range(G6P3D11.shape[0]):
    plt.errorbar(np.array(G6P3D11_position)*shifted_factor[row]/15,G6P3D11[row,:],G6P3D11_rms[row,:],fmt=fmts[row],color=colors[0],capsize=1,markersize=6,markerfacecolor='none')

for row in range(G6P3D12.shape[0]):
    plt.errorbar(np.array(G6P3D12_position)*shifted_factor[row]/15,G6P3D12[row,:],G6P3D12_rms[row,:],fmt=fmts[row],color=colors[1],capsize=1,markersize=6,markerfacecolor='none')

for row in range(G6P3D13.shape[0]):
    plt.errorbar(np.array(G6P3D13_position)*shifted_factor[row]/15,G6P3D13[row,:],G6P3D13_rms[row,:],fmt=fmts[row],color=colors[2],capsize=1,markersize=6,markerfacecolor='none')

for row in range(G6P3D14.shape[0]):
    plt.errorbar(np.array(G6P3D14_position)*shifted_factor[row]/15,G6P3D14[row,:],G6P3D14_rms[row,:],fmt=fmts[row],color=colors[3],capsize=1,markersize=6,markerfacecolor='none')
    
plt.plot(x_smooth, y_smooth, 'k--', linewidth=1, label='Spline Fit')
plt.plot(x_smooth+0.796, y_smooth, 'k-', linewidth=2, label='Spline Fit')
plt.xlim(9.75,15)
plt.ylim(0.075,0.275)
plt.xlabel('Position', fontsize=14)
plt.ylabel('1 - Normalized Current', fontsize=14)
#plt.legend()
plt.grid(True, alpha=0.3)
plt.savefig('spline_G6(20260204).svg', format='svg', dpi=300, bbox_inches='tight')

# %%
Ru_G6P3D11_position = [11, 11, 11, 11, 11]
Ru_G6P3D11 = np.array([
    [0.1199, np.nan, np.nan, np.nan, np.nan],
    [0.1169, 0.2241, np.nan, np.nan, np.nan],
    [0.1205, 0.1301, 0.1541, 0.1698, np.nan],
    [0.1297, 0.1511, 0.1745, 0.1988, 0.2185],
    [0.1566, 0.1729, 0.1872, 0.2106, 0.2406]
])
Ru_G6P3D11_rms = np.array([
    [0.0076, np.nan, np.nan, np.nan, np.nan],
    [0.0108, 0.0063, np.nan, np.nan, np.nan],
    [0.0120, 0.0062, 0.0061, 0.0090, np.nan],
    [0.0088, 0.0089, 0.0057, 0.0070, 0.0050],
    [0.0176, 0.0043, 0.0063, 0.0078, 0.0086]
])
for col in range(data.shape[1]):
    if col > 0 and col < 3:
        col_data = data[:,col]
        #plt.plot(np.array(nt_position[col])*shifted_factor/15,col_data,'ko')

for row in range(Ru_G6P3D11.shape[0]):
    plt.errorbar(np.array(Ru_G6P3D11_position)*shifted_factor[row]/15,Ru_G6P3D11[row,:],Ru_G6P3D11_rms[row,:],fmt=fmts[row],color=colors[3],capsize=2,markersize=6,markerfacecolor='none')
        
plt.plot(x_smooth, y_smooth, 'k-', linewidth=1, label='Spline Fit')
#plt.plot(x_smooth+0.9, y_smooth, '--', linewidth=1, label='Spline Fit')
#plt.plot(x_smooth, y_smooth-0.03, '--', linewidth=1, label='Spline Fit')
plt.xlim(9.75,15)
plt.ylim(0.105,0.275)
plt.xlabel('Position')
plt.ylabel('Normalized Current')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
Ru_G6P3D12_position = [12, 12, 12, 12]
Ru_G6P3D12 = np.array([
    [0.1105, 0.1373, 0.2316, np.nan],
    [0.1318, 0.1502, 0.1661, 0.1859],
    [0.1352, 0.1572, 0.1685, 0.1976],
    [0.1265, 0.1468, 0.1714, 0.2161],
    [0.1487, 0.1682, 0.2023, 0.2303]#, 0.2484
])
Ru_G6P3D12_rms = np.array([
    [0.0076, 0.0089, 0.0111, np.nan],
    [0.0067, 0.0059, 0.0067, 0.0056],
    [0.0081, 0.0054, 0.0089, 0.0068],
    [0.0066, 0.0092, 0.0052, 0.0051],
    [0.0054, 0.0082, 0.0060, 0.0045]#, 0.0048
])
for col in range(data.shape[1]):
    if col > 2 and col < 4:
        col_data = data[:,col]
        #plt.plot(np.array(nt_position[col])*shifted_factor/15,col_data,'ko')

for row in range(Ru_G6P3D12.shape[0]):
    #plt.plot(np.array(Ru_G6P3D12_position)*shifted_factor[row]/15,Ru_G6P3D12[row,:],'s',markerfacecolor='none')
    plt.errorbar(np.array(Ru_G6P3D12_position)*shifted_factor[row]/15,Ru_G6P3D12[row,:],Ru_G6P3D12_rms[row,:],fmt=fmts[row],color=colors[3],capsize=2,markersize=6,markerfacecolor='none')
        
plt.plot(x_smooth, y_smooth, 'k-', linewidth=1, label='Spline Fit')
#plt.plot(x_smooth+0.9, y_smooth, '--', linewidth=1, label='Spline Fit')
#plt.plot(x_smooth, y_smooth-0.03, '--', linewidth=1, label='Spline Fit')
plt.xlim(9.75,15)
plt.ylim(0.105,0.275)
plt.xlabel('Position')
plt.ylabel('Normalized Current')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
Ru_G6P3D13_position = [13, 13, 13, 13]
Ru_G6P3D13 = np.array([
    [0.1412, np.nan, np.nan, np.nan],
    [0.1178, 0.1328, 0.1510, np.nan],
    [0.1168, 0.1407, 0.1462, 0.1905],
    [0.1688, 0.1746, np.nan, np.nan],#, 0.2240
    [0.1083, 0.1451, 0.1765, 0.1955]
])

Ru_G6P3D13_rms = np.array([
    [0.0102, np.nan, np.nan, np.nan],
    [0.0072, 0.0062, 0.0100, np.nan],
    [0.0073, 0.0036, 0.0126, 0.0068],
    [0.0166, 0.0100, np.nan, np.nan],#, 0.0047
    [0.0084, 0.0144, 0.0090, 0.0061]
])

for col in range(data.shape[1]):
    if col > 2 and col < 4:
        col_data = data[:,col]
        #plt.plot(np.array(nt_position[col])*shifted_factor/15,col_data,'ko')

for row in range(Ru_G6P3D13.shape[0]):
    #plt.plot(np.array(Ru_G6P3D13_position)*shifted_factor[row]/15,Ru_G6P3D13[row,:],'s',markerfacecolor='none')
    plt.errorbar(np.array(Ru_G6P3D13_position)*shifted_factor[row]/15,Ru_G6P3D13[row,:],Ru_G6P3D13_rms[row,:],fmt=fmts[row],color=colors[3],capsize=2,markersize=6,markerfacecolor='none')
      
plt.plot(x_smooth, y_smooth, 'k-', linewidth=1, label='Spline Fit')
#plt.plot(x_smooth+0.9, y_smooth, '--', linewidth=1, label='Spline Fit')
#plt.plot(x_smooth, y_smooth-0.03, '--', linewidth=1, label='Spline Fit')
plt.xlim(9.75,15)
plt.ylim(0.105,0.275)
plt.xlabel('Position')
plt.ylabel('Normalized Current')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
Ru_G6P3D14_position = [14, 14, 14, 14]
Ru_G6P3D14 = np.array([
    [0.1724, 0.2400, np.nan, np.nan],
    [0.1569, 0.1733, 0.1786, 0.1936],
    [0.1451, 0.1768, 0.1990, np.nan],
    [0.1561, 0.1683, 0.1919, np.nan],
    [0.1150, 0.1561, 0.1720, 0.1805] #, 0.2029
])

Ru_G6P3D14_rms = np.array([
    [0.0066, 0.0074, np.nan, np.nan],
    [0.0066, 0.0057, 0.0099, 0.0061],
    [0.0068, 0.0098, 0.0058, np.nan],
    [0.0103, 0.0073, 0.0141, np.nan],
    [0.0087, 0.0122, 0.0040, 0.0065] #, 0.0100
])

for col in range(data.shape[1]):
    if col > 2 and col < 4:
        col_data = data[:,col]
        #plt.plot(np.array(nt_position[col])*shifted_factor/15,col_data,'ko')

for row in range(Ru_G6P3D14.shape[0]):
    #plt.plot(np.array(Ru_G6P3D14_position)*shifted_factor[row]/15,Ru_G6P3D14[row,:],'s',markerfacecolor='none')
    plt.errorbar(np.array(Ru_G6P3D14_position)*shifted_factor[row]/15,Ru_G6P3D14[row,:],Ru_G6P3D14_rms[row,:],fmt=fmts[row],color=colors[3],capsize=2,markersize=6,markerfacecolor='none')
        
plt.plot(x_smooth, y_smooth, 'k-', linewidth=1, label='Spline Fit')
#plt.plot(x_smooth+0.9, y_smooth, '--', linewidth=1, label='Spline Fit')
#plt.plot(x_smooth, y_smooth-0.03, '--', linewidth=1, label='Spline Fit')
plt.xlim(9.75,15)
plt.ylim(0.105,0.275)
plt.xlabel('Position')
plt.ylabel('Normalized Current')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
colors = ['#1466b8ff', '#3380ccff', '#7099c2ff', '#174d82ff']
fmts = ['^','s','p','h','o']

fig, ax = plt.subplots(figsize=(4, 4))

for row in range(Ru_G6P3D11.shape[0]):
    plt.errorbar(np.array(Ru_G6P3D11_position)*shifted_factor[row]/15,Ru_G6P3D11[row,:],Ru_G6P3D11_rms[row,:],fmt=fmts[row],color=colors[0],capsize=1,markersize=6,markerfacecolor='none')

for row in range(Ru_G6P3D12.shape[0]):
    plt.errorbar(np.array(Ru_G6P3D12_position)*shifted_factor[row]/15,Ru_G6P3D12[row,:],Ru_G6P3D12_rms[row,:],fmt=fmts[row],color=colors[1],capsize=1,markersize=6,markerfacecolor='none')

for row in range(Ru_G6P3D13.shape[0]):
    plt.errorbar(np.array(Ru_G6P3D13_position)*shifted_factor[row]/15,Ru_G6P3D13[row,:],Ru_G6P3D13_rms[row,:],fmt=fmts[row],color=colors[2],capsize=1,markersize=6,markerfacecolor='none')

for row in range(Ru_G6P3D14.shape[0]):
    plt.errorbar(np.array(Ru_G6P3D14_position)*shifted_factor[row]/15,Ru_G6P3D14[row,:],Ru_G6P3D14_rms[row,:],fmt=fmts[row],color=colors[3],capsize=1,markersize=6,markerfacecolor='none')
    
plt.plot(x_smooth, y_smooth, 'k-', linewidth=2, label='Spline Fit')
plt.plot(x_smooth+0.796, y_smooth, 'k--', linewidth=1, label='Spline Fit')
plt.xlim(9.75,15)
plt.ylim(0.075,0.275)
plt.xlabel('Position', fontsize=14)
plt.ylabel('1 - Normalized Current', fontsize=14)
#plt.legend()
plt.grid(True, alpha=0.3)
plt.savefig('spline_G6_Ru(260205).svg', format='svg', dpi=300, bbox_inches='tight')
